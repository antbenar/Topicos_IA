# %% [markdown]
# # Proyecto Parcial:
# ## Predictor de casos confirmados y muertes por Covid-19 en Arequipa y en Perú

# %%
##Funciones Auxiliares para guardar las imagenes ploteadas

# Common imports
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import pandas  as pd

# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    if not os.path.isdir(IMAGES_PATH):
        os.makedirs(IMAGES_PATH)
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %% [markdown]
# # Obteniendo los datos
# Los datos usados en este proyecto fueron obtenidos del siguiente repositorio: https://github.com/jmcastagnetto/covid-19-peru-data/blob/main/datos. Este repositorio cuenta con datos oficiales del MINSA, los cuales son libres de uso y actualizados.

# %% [markdown]
# Cargar el csv del link del repositorio de datos covid-19

# %%
url = 'https://raw.githubusercontent.com/jmcastagnetto/covid-19-peru-data/main/datos/covid-19-peru-data.csv'
covid_data = pd.read_csv(url)
covid_data.tail()
# Out:
#      country iso3c      region        date  confirmed   deaths  recovered  \
# 5391    Peru   PER  San Martín  2020-10-11    19187.0    715.0        NaN
# 5392    Peru   PER       Tacna  2020-10-11    12341.0    222.0        NaN
# 5393    Peru   PER      Tumbes  2020-10-11     7636.0    305.0        NaN
# 5394    Peru   PER     Ucayali  2020-10-11    16883.0    328.0        NaN
# 5395    Peru   PER         NaN  2020-10-11   849371.0  33305.0   743969.0
#
#       total_tests  negative_tests  pcr_test_positive  \
# 5391      77575.0         58388.0             2702.0
# 5392      65780.0         53439.0             1591.0
# 5393      32597.0         24961.0              697.0
# 5394      53856.0         36973.0             1035.0
# 5395    4077357.0       3227986.0           193260.0
#
#       serological_test_positive  pcr_serological_test_positive
# 5391                    16485.0                            NaN
# 5392                    10750.0                            NaN
# 5393                     6939.0                            NaN
# 5394                    15848.0                            NaN
# 5395                   656111.0                            NaN

# %% [markdown]
# Mostrar un resumen de las columnas del conjunto de datos

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5396 entries, 0 to 5395
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        5396 non-null   object
#  1   iso3c                          5396 non-null   object
#  2   region                         5177 non-null   object
#  3   date                           5396 non-null   object
#  4   confirmed                      5240 non-null   float64
#  5   deaths                         4642 non-null   float64
#  6   recovered                      237 non-null    float64
#  7   total_tests                    4105 non-null   float64
#  8   negative_tests                 4137 non-null   float64
#  9   pcr_test_positive              4749 non-null   float64
#  10  serological_test_positive      4685 non-null   float64
#  11  pcr_serological_test_positive  24 non-null     float64
# dtypes: float64(8), object(4)
# memory usage: 506.0+ KB

# %% [markdown]
# Descibir estadisticamente los datos

# %%
covid_data.describe()
# Out:
#            confirmed        deaths      recovered   total_tests  \
# count    5240.000000   4642.000000     237.000000  4.105000e+03
# mean    25632.315267   1167.600819  205489.932489  1.720466e+05
# std     91078.856685   3990.426543  229112.434312  5.137445e+05
# min         1.000000      1.000000       1.000000  3.250000e+03
# 25%       534.500000     24.000000    6541.000000  2.226500e+04
# 50%      4207.500000    177.500000  119409.000000  4.311000e+04
# 75%     14140.000000    672.750000  348006.000000  8.075900e+04
# max    849371.000000  33305.000000  743969.000000  4.077357e+06
#
#        negative_tests  pcr_test_positive  serological_test_positive  \
# count    4.137000e+03        4749.000000                4685.000000
# mean     1.384693e+05        6855.596547               21134.634152
# std      4.115240e+05       24565.195500               69773.804636
# min     -2.767580e+05           1.000000                   1.000000
# 25%      1.862500e+04         163.000000                 853.000000
# 50%      3.523700e+04         850.000000                4573.000000
# 75%      6.421600e+04        2469.000000               13199.000000
# max      3.227986e+06      193260.000000              656111.000000
#
#        pcr_serological_test_positive
# count                      24.000000
# mean                       34.583333
# std                        72.926358
# min                         1.000000
# 25%                         1.750000
# 50%                         3.000000
# 75%                         6.250000
# max                       231.000000

# %% [markdown]
# Plotear histogramas de cada categoría que contiene el conjunto de datos

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
covid_data.hist(bins=50, figsize=(20,15))
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["deaths", "confirmed", "date"]
scatter_matrix(covid_data[attributes], figsize=(12, 8), alpha=0.1)
save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot

# %% [markdown]
# ### Preparando los datos

# %% [markdown]
# Para hacer la tarea de regresión solo usaremos los datos que nos conciernen los cuales son:
#  <ul>
#     <li>Fecha (date)</li>
#     <li>Departamentos (region)</li>
#     <li>Casos confirmados (confirmed)</li>
#     <li>Personas fallecidas (deaths)</li>
#  </ul>

# %%
#hacer una copia de los datos originales antes de modificarlos
covid_data_backup = covid_data

covid_data = covid_data.drop(['country','iso3c','recovered','negative_tests',
                            'pcr_test_positive','serological_test_positive','pcr_serological_test_positive'], axis=1)

# %% [markdown]
# Reordenar los datos de tal manera que total tests se encuentre en la segunda columna para facilitar la división de los datos más adelante.

# %%
columns_titles = ["region", "date", "total_tests", "confirmed","deaths"]
covid_data = covid_data.reindex(columns=columns_titles)

# %%
covid_data.head()
# Out:
#   region        date  total_tests  confirmed  deaths
# 0    NaN  2020-03-06          NaN        1.0     NaN
# 1    NaN  2020-03-07          NaN        6.0     NaN
# 2    NaN  2020-03-09          NaN        9.0     NaN
# 3    NaN  2020-03-10          NaN       11.0     NaN
# 4    NaN  2020-03-11          NaN       17.0     NaN

# %% [markdown]
# La fecha está en formato string <b>2020-03-06</b>, por lo que para establecer una correlación temporal en los datos, la convertiremos a un valor entero. Y analizando mejor, sería mejor si enumeramos los días trancurridos desde el inicio de la pandemia, para que así la fecha tenga secuencialidad de un día para el otro, por lo que tendremos dos conjuntos de datos:
# <ul>
#     <li><b>covid_data:</b> Un conjunto de datos con las fechas transformadas a entero <b>2020-03-06</b> -> <b>20200306	</b></li>
#     <li><b>covid_data_sequential:</b> Y otro conjunto de datos con una secuencialidad en los día iniciando desde el primer día de la pandemia en Perú.</li>
#  </ul>

# %%
#volvemos entero el dia en covid_data
import datetime
covid_data['date'] = pd.to_datetime(covid_data['date']).dt.strftime("%Y%m%d").astype(int)

# %%
covid_data.head()
# Out:
#   region      date  total_tests  confirmed  deaths
# 0    NaN  20200306          NaN        1.0     NaN
# 1    NaN  20200307          NaN        6.0     NaN
# 2    NaN  20200309          NaN        9.0     NaN
# 3    NaN  20200310          NaN       11.0     NaN
# 4    NaN  20200311          NaN       17.0     NaN

# %% [markdown]
# Verificamos la efectividad de los cambios realizados empleando la scatter_matrix

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["deaths", "confirmed", "date"]
scatter_matrix(covid_data[attributes], figsize=(12, 8), alpha=0.1)
save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot

# %% [markdown]
# Se observa de la matriz de dispersión que no hay una secuencialidad de los datos empleando la fecha en formato entero, así que para solucionar este problema usaremos <b>covid_data_sequential</b>, el cual funciona asignando una sequencialidad empezando desde el día número uno.

# %%
covid_data['date'] = covid_data.index + 1
covid_data.head()
# Out:
#   region  date  total_tests  confirmed  deaths
# 0    NaN     1          NaN        1.0     NaN
# 1    NaN     2          NaN        6.0     NaN
# 2    NaN     3          NaN        9.0     NaN
# 3    NaN     4          NaN       11.0     NaN
# 4    NaN     5          NaN       17.0     NaN

# %% [markdown]
# Volvemos ha realizar una verificación de los datos en la matriz de dispersión y se puede observar una sequencialidad mucho mayor en los datos, ya se observa el comportamiento exponencial que tienen los casos confirmados y las muertes

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["deaths", "confirmed", "date"]
scatter_matrix(covid_data[attributes], figsize=(12, 8), alpha=0.1)
save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot

# %% [markdown]
# Reemplazamos los nan de la columna de muertes con el valor 0. Posteriormente este campo volverá a ser modificado.

# %%
covid_data_backup = covid_data.copy()

covid_data['deaths'].fillna(0, inplace=True)

#verificar si no quedan campos de muerte vacios
ind = np.where(np.isnan(covid_data['deaths']))
print('campos de muerte vacios: ' + str(len(ind[0])))

covid_data.head()
# Out:
# campos de muerte vacios: 0
#   region  date  total_tests  confirmed  deaths
# 0    NaN     1          NaN        1.0     0.0
# 1    NaN     2          NaN        6.0     0.0
# 2    NaN     3          NaN        9.0     0.0
# 3    NaN     4          NaN       11.0     0.0
# 4    NaN     5          NaN       17.0     0.0

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["deaths", "confirmed", "date"]
scatter_matrix(covid_data[attributes], figsize=(12, 8), alpha=0.1)
save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot

# %% [markdown]
# ### Dividiendo los datos
#
# <b>Dividir el conjunto de datos en solo los que corresponden a Arequipa y en su totalidad a Perú.</b>
#
# Los datos que se encuentran con Nan en la columna de la región es el acumulado de todas las regiones, por lo tanto son los casos de covid en el Perú.

# %%
data_peru = covid_data.loc[pd.isnull(covid_data['region'])]
data_peru = data_peru.drop(['region'], axis=1)
data_peru.head(50)
# Out:
#      date  total_tests  confirmed  deaths
# 0       1          NaN        1.0     0.0
# 1       2          NaN        6.0     0.0
# 2       3          NaN        9.0     0.0
# 3       4          NaN       11.0     0.0
# 4       5          NaN       17.0     0.0
# 5       6          NaN       22.0     0.0
# 11     12          NaN       38.0     0.0
# 17     18          NaN       43.0     0.0
# 28     29          NaN       71.0     0.0
# 39     40          NaN       86.0     0.0
# 51     52          NaN      117.0     0.0
# 64     65          NaN      145.0     0.0
# 77     78          NaN      234.0     3.0
# 91     92          NaN      263.0     4.0
# 105   106          NaN      318.0     5.0
# 119   120          NaN      361.0     5.0
# 134   135          NaN      395.0     5.0
# 150   151          NaN      416.0     7.0
# 167   168          NaN      480.0     9.0
# 184   185          NaN      580.0     9.0
# 202   203          NaN      635.0    11.0
# 220   221          NaN      671.0    16.0
# 240   241          NaN      852.0    18.0
# 260   261          NaN      950.0    24.0
# 280   281          NaN     1065.0    30.0
# 301   302          NaN     1323.0    47.0
# 322   323          NaN     1414.0    55.0
# 344   345          NaN     1595.0    61.0
# 366   367          NaN     1746.0    73.0
# 389   390          NaN     2281.0    83.0
# 412   413          NaN     2561.0    92.0
# 436   437          NaN     2954.0   107.0
# 461   462      39599.0     4342.0   121.0
# 486   487      48465.0     5256.0   138.0
# 512   513      56681.0     5897.0   169.0
# 538   539      65712.0     6848.0   181.0
# 564   565      76322.0     7519.0   193.0
# 590   591      87166.0     9784.0   216.0
# 616   617     101985.0    10303.0   230.0
# 642   643     109385.0    11475.0   254.0
# 668   669     121468.0    12491.0   274.0
# 694   695     127513.0    13489.0   300.0
# 720   721     135895.0    14420.0   348.0
# 746   747     143745.0    15628.0   400.0
# 772   773     148011.0    16325.0   445.0
# 798   799     156208.0    17837.0   484.0
# 824   825     170400.0    19250.0   530.0
# 850   851     185238.0    20914.0   572.0
# 876   877     198349.0    21648.0   634.0
# 902   903     218195.0    25331.0   700.0

# %%
data_aqp = covid_data.loc[covid_data['region'] == 'Arequipa']
data_aqp = data_aqp.drop(['region'], axis=1)
data_aqp.head(50)
# Out:
#       date  total_tests  confirmed  deaths
# 6        7          NaN        2.0     0.0
# 12      13          NaN        2.0     0.0
# 19      20          NaN        2.0     0.0
# 30      31          NaN        2.0     0.0
# 41      42          NaN        2.0     0.0
# 53      54          NaN        2.0     0.0
# 66      67          NaN        3.0     0.0
# 79      80          NaN        3.0     0.0
# 93      94          NaN        4.0     0.0
# 107    108          NaN        7.0     0.0
# 121    122          NaN        7.0     0.0
# 136    137          NaN        9.0     0.0
# 152    153          NaN       10.0     0.0
# 169    170          NaN       15.0     0.0
# 186    187          NaN       15.0     0.0
# 204    205          NaN       15.0     0.0
# 222    223          NaN       15.0     0.0
# 242    243          NaN       21.0     0.0
# 262    263          NaN       26.0     0.0
# 282    283          NaN       30.0     1.0
# 303    304          NaN       30.0     1.0
# 325    326          NaN       37.0     1.0
# 347    348          NaN       37.0     2.0
# 369    370          NaN       51.0     3.0
# 392    393          NaN       60.0     4.0
# 415    416          NaN       66.0     4.0
# 440    441          NaN       74.0     5.0
# 465    466          NaN       77.0     4.0
# 490    491          NaN       83.0     4.0
# 516    517          NaN       85.0     4.0
# 542    543          NaN       86.0     0.0
# 568    569          NaN       98.0     0.0
# 594    595          NaN       99.0     5.0
# 620    621          NaN       98.0     5.0
# 646    647          NaN      111.0     5.0
# 672    673          NaN      134.0     5.0
# 698    699          NaN      146.0     5.0
# 724    725          NaN      192.0     5.0
# 750    751          NaN      229.0     8.0
# 776    777          NaN      273.0     8.0
# 802    803          NaN      276.0     8.0
# 828    829          NaN      291.0     8.0
# 854    855          NaN      311.0    10.0
# 880    881          NaN      364.0    10.0
# 906    907          NaN      396.0    10.0
# 932    933          NaN      479.0    11.0
# 958    959          NaN      501.0    11.0
# 984    985          NaN      529.0    11.0
# 1010  1011          NaN      571.0    11.0
# 1036  1037          NaN      624.0    11.0

# %% [markdown]
# Como se puede observar, las pruebas totales no se encuentran en su totalidad en el dataset, por lo que lo que haremos será generar de manera sintética estos valores. Para ello calcularemos una relación entre los casos confirmados y los días transcurridos.

# %% [markdown]
# Calcular la tasa de crecimiento de los tests

# %%
crecimiento_tests_peru = np.zeros(len(data_peru) - 1)

for i in range(1,len(data_peru)):
    crecimiento_tests_peru[i-1] = data_peru.iloc[i,1] / data_peru.iloc[i-1,1]

#obtener la tasa de crecimiento para aquellos datos que no cuenten con esta segun los dos datos posteriores
indices = np.where(np.isnan(crecimiento_tests_peru))

for idx in reversed(indices[0]):
    crecimiento_tests_peru[idx] = 2*crecimiento_tests_peru[idx+1] - crecimiento_tests_peru[idx+2]

#plotear Tasa de cambio de tests 
fig, ax = plt.subplots(1, 1, figsize=(15,5))
ax.plot(crecimiento_tests_peru)
ax.set_title("Tasa de cambio de tests")
# Out:
# Text(0.5, 1.0, 'Tasa de cambio de tests')

# %% [markdown]
# Adicionar los tests al conjunto de datos

# %%
#datos de peru
indices = np.where(np.isnan(data_peru['total_tests']))
for idx in reversed(indices[0]):
    data_peru.iloc[idx,1] = data_peru.iloc[idx+1,1]  / crecimiento_tests_peru[idx]
   
#datos de arequipa
indices = np.where(np.isnan(data_peru['total_tests']))
for idx in reversed(indices[0]):
    data_peru.iloc[idx,1] = data_peru.iloc[idx+1,1]  / crecimiento_tests_peru[idx]
    
#plotear casos confirmados 
fig, ax = plt.subplots(1, 1, figsize=(15,5))
ax.plot(data_peru.iloc[:32,0], data_peru.iloc[:32,1], c="red", label='Tasa predicha')
ax.plot(data_peru.iloc[31:,0], data_peru.iloc[31:,1], c="blue", label='Tasa real')
ax.set_title("Tasa de los test Totales / Dia")
ax.set_ylabel('Tasa de los test Totales')
ax.set_xlabel('Dias')
ax.legend()

# %% [markdown]
# En los datos de arequipa mostrados en la celda anterior, se puede percatar que en las filas <b>542</b> y <b>568</b> los datos son 0, cuando estos deberían ser un acumulado del día anterior, es por esto que rellenaremos esos datos con el último acumulado valido.

# %%
data_peru['deaths'].replace(0, method='ffill', inplace=True)
data_aqp['deaths'].replace(0, method='ffill', inplace=True)
data_aqp.head(50)
# Out:
#       date  total_tests  confirmed  deaths
# 6        7          NaN        2.0     0.0
# 12      13          NaN        2.0     0.0
# 19      20          NaN        2.0     0.0
# 30      31          NaN        2.0     0.0
# 41      42          NaN        2.0     0.0
# 53      54          NaN        2.0     0.0
# 66      67          NaN        3.0     0.0
# 79      80          NaN        3.0     0.0
# 93      94          NaN        4.0     0.0
# 107    108          NaN        7.0     0.0
# 121    122          NaN        7.0     0.0
# 136    137          NaN        9.0     0.0
# 152    153          NaN       10.0     0.0
# 169    170          NaN       15.0     0.0
# 186    187          NaN       15.0     0.0
# 204    205          NaN       15.0     0.0
# 222    223          NaN       15.0     0.0
# 242    243          NaN       21.0     0.0
# 262    263          NaN       26.0     0.0
# 282    283          NaN       30.0     1.0
# 303    304          NaN       30.0     1.0
# 325    326          NaN       37.0     1.0
# 347    348          NaN       37.0     2.0
# 369    370          NaN       51.0     3.0
# 392    393          NaN       60.0     4.0
# 415    416          NaN       66.0     4.0
# 440    441          NaN       74.0     5.0
# 465    466          NaN       77.0     4.0
# 490    491          NaN       83.0     4.0
# 516    517          NaN       85.0     4.0
# 542    543          NaN       86.0     4.0
# 568    569          NaN       98.0     4.0
# 594    595          NaN       99.0     5.0
# 620    621          NaN       98.0     5.0
# 646    647          NaN      111.0     5.0
# 672    673          NaN      134.0     5.0
# 698    699          NaN      146.0     5.0
# 724    725          NaN      192.0     5.0
# 750    751          NaN      229.0     8.0
# 776    777          NaN      273.0     8.0
# 802    803          NaN      276.0     8.0
# 828    829          NaN      291.0     8.0
# 854    855          NaN      311.0    10.0
# 880    881          NaN      364.0    10.0
# 906    907          NaN      396.0    10.0
# 932    933          NaN      479.0    11.0
# 958    959          NaN      501.0    11.0
# 984    985          NaN      529.0    11.0
# 1010  1011          NaN      571.0    11.0
# 1036  1037          NaN      624.0    11.0

# %% [markdown]
# Verificamos la efectividad de los cambios realizados empleando la scatter_matrix

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["deaths", "confirmed", "date"]
scatter_matrix(covid_data[attributes], figsize=(12, 8), alpha=0.1)
save_fig("scatter_matrix_plot")

# %% [markdown]
# # Preparar los datos para la regresión multivariada

# %% [markdown]
# <b>Normalizar los datos</b>

# %%
def Normalizar_Datos( data ):
    mean = np.nanmean(data, axis=0)
    standard = np.nanstd(data, axis=0)
    print (mean, standard)
    data = (data - mean)/standard
    return data

# %%
data_peru = Normalizar_Datos(data_peru)
data_peru.head()

# %% [markdown]
# <h3>Datos de Perú</h3>
#
# El conjunto de datos de entrenamiento fue generado usando un 80% del conjunto de datos total (equivalente al ranfo entre  <b>13/03/2020</b> y <b>29/08/2020</b>), y se mantuvo la secuencialidad por lo que no se realizó ningun intercambio de posiciones (shuffle=False).

# %% [markdown]
# <b>División de conjunto de entrenamiento y de prueba</b>

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(data_peru, test_size=0.2, shuffle=False)

# %%
train_set.head()

# %%
test_set.head()

# %% [markdown]
# <b>Dividir los datos en conjunto de datos de casos confirmados y conjunto de datos de decesos</b>

# %%
#Conjunto de datos de decesos
#train data
train_decesos_peru = train_set.copy()
train_decesos_peru = train_decesos_peru.drop(['confirmed'], axis=1)
train_decesos_peru.info()
print('_____________________________')

#test data
test_decesos_peru = test_set.copy()
test_decesos_peru = test_decesos_peru.drop(['confirmed'], axis=1)
test_decesos_peru.info()

# %%
#Conjunto de datos de casos confirmados
#train data
train_confirmados_peru = train_set.copy()
train_confirmados_peru = train_confirmados_peru.drop(['deaths'], axis=1)
train_confirmados_peru.info()
print('_____________________________')
#test data
test_confirmados_peru = test_set.copy()
test_confirmados_peru = test_confirmados_peru.drop(['deaths'], axis=1)
test_confirmados_peru.info()

# %% [markdown]
# <b>Dividir el input del output y los casos confirmados de los decesos

# %%
train_confirmados_peru_X = train_confirmados_peru.iloc[:,0:-1]
train_confirmados_peru_y = train_confirmados_peru.iloc[:,-1:]
test_confirmados_peru_X = test_confirmados_peru.iloc[:,0:-1]
test_confirmados_peru_y = test_confirmados_peru.iloc[:,-1:]

# %%
train_confirmados_peru_X.head()

# %%
train_confirmados_peru_y.head()

# %% [markdown]
# <b>Agregar una columna de unos al conjunto de entrenamiento y al conjunto de prueba</b>

# %%
num_elements_train = len(train_confirmados_peru_y)
num_elements_test = len(test_confirmados_peru_y)

train_confirmados_peru_X = np.concatenate((np.ones([num_elements_train, 1]), train_confirmados_peru_X), axis=1)
test_confirmados_peru_X = np.concatenate((np.ones([num_elements_test, 1]), test_confirmados_peru_X), axis=1)

# %%
print(train_confirmados_peru_X.shape)
print(train_confirmados_peru_X)

# %%
print(test_confirmados_peru_X.shape)
print(test_confirmados_peru_X)

# %% [markdown]
# # Modelo de regresor lineal

# %% [markdown]
# Funciones que forman parte del regresor lineal

# %%
def calcular_Costo(X, Y, Theta):
    m = len(X)
    cost = np.sum((X.dot(Theta.T) - Y)**2) / (2 * m)
    return cost

def predict(X, theta):
    return X.dot(theta.T)

def gradiente_Descendiente(X, Y, theta, iteraciones, tasa):
    costos = [0]*iteraciones
    m = len(X)
    for itr in range(iteraciones):
        h = predict(X, theta)
        dif = h - Y
        derivada = (X.T).dot(dif) / m
        theta = theta - (tasa * derivada).T
        
        costos[itr] = calcular_Costo(X, Y, theta)
    return theta, costos

# %% [markdown]
# Ejecutar el gradiente descendiente para el <b>conjunto de datos de Perú</b>

# %%
n_features = train_confirmados_peru_X.shape[1]
theta_confirmados_peru = np.zeros(n_features)[np.newaxis]
print(train_confirmados_peru_X)
theta_confirmados_peru, costos_confirmados_peru = gradiente_Descendiente(train_confirmados_peru_X, train_confirmados_peru_y, 
                                                theta_confirmados_peru, 1000, 0.1)

# %%
print(theta_confirmados_peru)

# %%
predict_confirmados_peru = predict( test_confirmados_peru_X ,theta_confirmados_peru)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))

#plotear casos confirmados 
ax[0].scatter(test_confirmados_peru_X[:,1], test_confirmados_peru_y, alpha=0.1, c="red")
ax[0].scatter(test_confirmados_peru_X[:,1], predict_confirmados_peru, alpha=1.0, c="purple")
ax[0].plot(train_confirmados_peru_X[:,1], train_confirmados_peru_y, "-o")
ax[0].set_title("Date_Deaths")
ax[0].set_ylabel('Muertes')
ax[0].set_xlabel('Dias')

#plotear muertes
ax[1].scatter(test_confirmados_peru_X[:,1], test_confirmados_peru_y, alpha=0.9, c="red")
ax[1].scatter(test_confirmados_peru_X[:,1], predict_confirmados_peru, alpha=0.8, c="purple")
ax[1].plot(train_confirmados_peru_X[:,1], train_confirmados_peru_y, "-o")
ax[1].set_title("Date_Deaths")
ax[1].set_ylabel('Muertes')
ax[1].set_xlabel('Dias')
